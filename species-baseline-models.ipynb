# %%
from kaggle_secrets import UserSecretsClient
import os

user_secrets = UserSecretsClient()
kaggle_key = user_secrets.get_secret("key")
kaggle_username = user_secrets.get_secret("username")

os.environ['KAGGLE_KEY'] = kaggle_key
os.environ['KAGGLE_USERNAME'] = kaggle_username

# %%
# !kaggle kernels output justinrwong/create-df-individuals-over-5 -p /kaggle/working

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# %% [markdown]
# ## References
# https://towardsdatascience.com/illustrated-10-cnn-architectures-95d78ace614d

# %%
fn = "./batch_processed/processed_batch_df_individuals_over_5_pics.csv"
df = pd.read_csv(fn)

# %%
print(df.shape)
df.head()

# %%
from sklearn.model_selection import train_test_split
import cv2

import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
x_cols = df.columns[4:].values
df_X = df[x_cols]
df_Y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_Y, test_size=0.2, random_state=2022)

# %%
example = df.sample()

# %%
example_img_path = "../input/happy-whale-and-dolphin/train_images/{}".format(example.image.iloc[0])

# %%
clf = DecisionTreeClassifier(random_state=0, max_depth=50)#model.summary()

# %%
cross_val_score(clf, X_train, y_train, cv=5)

# %%
sum([0.56489945, 0.58500914, 0.66849817, 0.58424908, 0.57875458])/ 5
